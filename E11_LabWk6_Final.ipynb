# %% [markdown]
# # Lab Activity Week 6
#
# **Homework** Anything you do not complete in lab is your homework. Please provide a link to your github repository as your homework submission.

# %% [markdown]
# ### Step 1 - Review: Comparing Indoor vs Outdoor data
# - Cut out any data that was part of your outdoor data set that was not taken outdoors or take a new outdoor data set that runs for an extra 30s to give you time to get outside and then cut out that 30s interval
#   - Recall we learned methods for slicing dataframes in week 2
# - Now produce histogram plots that compare indoors vs outdoors for each of your data types - don't forget labels
# - Compare the mean and standard deviation values for each set of indoor data versus outdoor data, are they in agreement?
#   - NOTE: The variance in your data is not the uncertainty on the mean (central limit theorem)
#   - what is your mean uncertainty?
#   - How many inside mean standard deviations (1 sigma uncertainty) are your inside and outside measurements separated by?
# - If your distributions were not well described by a Gaussian, do you think you took enough data for the central limit theorem to apply?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

outsideurl = "https://raw.githubusercontent.com/rgorai22/E11_RishikaKatieVic/main/FiveMinOutside.csv" 
outsidedf = pd.read_csv(outsideurl)

outsideurl2 = "Downloads\outsidedata_group2.csv"
outsidedf2 = pd.read_csv(outsideurl2)

insideurl = "https://raw.githubusercontent.com/rgorai22/E11_RishikaKatieVic/main/FiveMinutesInside.csv"
insidedf = pd.read_csv(insideurl)

insideurl2 = "Downloads\insidedata_group2.csv"
insidedf2 = pd.read_csv(insideurl2)

outsidedf = outsidedf[1:296]
display(outsidedf)
outsidedf.describe()
outsidedf2 = outsidedf2[1:554]
display(outsidedf2)
outsidedf2.describe()
insidedf = insidedf[1:297]
display(insidedf)
insidedf.describe()
insidedf2 = insidedf2[1:297]
display(insidedf2)
insidedf2.describe()
# Out:
#              Time  Pm25  Pm100       Temp     Gas   Humidity     Pressure  \
# 1    1.707957e+09     0      0  24.594453   22689  42.328480  1005.271764
# 2    1.707957e+09     1      1  24.623359   29622  42.236508  1005.244340
# 3    1.707957e+09     1      1  24.657734   37252  42.109519  1005.229004
# 4    1.707957e+09     1      1  24.692891   45424  41.964882  1005.213153
# 5    1.707957e+09     1      1  24.725703   56176  41.855711  1005.214458
# ..            ...   ...    ...        ...     ...        ...          ...
# 291  1.707958e+09     1      2  13.799531  261172  67.314556  1004.419332
# 292  1.707958e+09     1      2  13.799727  263155  67.368367  1004.423061
# 293  1.707958e+09     1      2  13.801094  263957  67.395461  1004.420117
# 294  1.707958e+09     1      2  13.801484  262557  67.469501  1004.419031
# 295  1.707958e+09     1      2  13.801680  264562  67.496438  1004.417634
#
#       Altitude
# 1    66.637026
# 2    66.866814
# 3    66.995326
# ...

# %%
plt.hist(outsidedf["Pm25"],label='Outside')
plt.hist(insidedf["Pm25"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Counts [PM25]')                       
plt.ylabel('Frequency')
plt.title("Counts of PM25 vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Pm100"],label='Outside')
plt.hist(insidedf["Pm100"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Counts [PM100]')                       
plt.ylabel('Frequency')
plt.title("Counts of PM100 vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Temp"],label='Outside')
plt.hist(insidedf["Temp"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Temperature [Degrees]')                       
plt.ylabel('Frequency')
plt.title("Temperature vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Gas"],label='Outside')
plt.hist(insidedf["Gas"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Gas [Counts]')                       
plt.ylabel('Frequency')
plt.title("Gas vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Humidity"],label='Outside')
plt.hist(insidedf["Humidity"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Humidity [g/kg]')                       
plt.ylabel('Frequency')
plt.title("Humidity vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Pressure"],label='Outside')
plt.hist(insidedf["Pressure"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Pressure')                       
plt.ylabel('Frequency')
plt.title("Pressure vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Altitude"],label='Outside')
plt.hist(insidedf["Altitude"],label='Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('Altitude')                       
plt.ylabel('Frequency')
plt.title("Altitude vs Frequency for Inside and Outside Data")                                  
plt.show()

# %%
sigmamin25 = (np.std(insidedf["Pm25"]))/np.sqrt(len(insidedf["Pm25"]))
meanin25 = np.mean(insidedf["Pm25"])
sigmamout25 = (np.std(outsidedf["Pm25"]))/np.sqrt(len(outsidedf["Pm25"]))
sigmam25 = (np.std(insidedf["Pm25"])+np.std(outsidedf["Pm25"]))/np.sqrt(len(outsidedf["Pm25"])+len(insidedf["Pm25"]))
meanout25 = np.mean(outsidedf["Pm25"])
meandiff25 = abs(meanin25-meanout25)
sigmam253 = 3*abs(sigmam25)

if sigmam253 < meandiff25:
    print("Pm25 data sets are statistically different!")
else:
    print("Pm25 data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pm25 mean uncertainty: {:.2f}".format(sigmam25))
sigdiffin25 = meandiff25 / sigmamin25
print("\033[1m For Pm25 the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffin25))
    
sigmam100 = (np.std(insidedf["Pm100"])+np.std(outsidedf["Pm100"]))/np.sqrt(len(outsidedf["Pm100"])+len(insidedf["Pm100"]))
sigmamin100 = (np.std(insidedf["Pm100"]))/np.sqrt(len(insidedf["Pm100"]))
meanin100 = np.mean(insidedf["Pm100"])
sigmamout100 = (np.std(outsidedf["Pm100"]))/np.sqrt(len(outsidedf["Pm100"]))
meanout100 = np.mean(outsidedf["Pm100"])
meandiff100 = abs(meanin100-meanout100)
sigmam1003 = 3*abs(sigmam100)

if sigmam1003 < meandiff100:
    print("Pm100 data sets are statistically different!")
else:
    print("Pm100 data sets are statistically similar, means within 3sigma of uncertainty of the mean.")
    
print("Pm100 mean uncertainty: {:.2f}".format(sigmam100))
sigdiffin100 = meandiff100 / sigmamin100
print("\033[1m For Pm100 the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffin100))

sigmaminTemp = (np.std(insidedf["Temp"]))/np.sqrt(len(insidedf["Temp"]))
meaninTemp = np.mean(insidedf["Temp"])
sigmamoutTemp = (np.std(outsidedf["Temp"]))/np.sqrt(len(outsidedf["Temp"]))
sigmamTemp = (np.std(insidedf["Temp"])+np.std(outsidedf["Temp"]))/np.sqrt(len(outsidedf["Temp"])+len(insidedf["Temp"]))
meanoutTemp = np.mean(outsidedf["Temp"])
meandiffTemp = abs(meaninTemp-meanoutTemp)
sigmamTemp3 = 3*abs(sigmamTemp)

if sigmamTemp3 < meandiffTemp:
    print("Temperature data sets are statistically different!")
else:
    print("Temperature data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Temperature mean uncertainty: {:.2f}".format(sigmamTemp))
sigdiffinTemp = meandiffTemp / sigmaminTemp
print("\033[1m For Temperature the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinTemp))


sigmaminGas = (np.std(insidedf["Gas"]))/np.sqrt(len(insidedf["Gas"]))
meaninGas = np.mean(insidedf["Gas"])
sigmamoutGas = (np.std(outsidedf["Gas"]))/np.sqrt(len(outsidedf["Gas"]))
sigmamGas = (np.std(insidedf["Gas"])+np.std(outsidedf["Gas"]))/np.sqrt(len(outsidedf["Gas"])+len(insidedf["Gas"]))
meanoutGas = np.mean(outsidedf["Gas"])
meandiffGas = abs(meaninGas-meanoutGas)
sigmamGas3 = 3*abs(sigmamGas)

if sigmamGas3 < meandiffGas:
    print("Gas data sets are statistically different!")
else:
    print("Gas data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Gas mean uncertainty: {:.2f}".format(sigmamGas))
sigdiffinGas = meandiffGas / sigmaminGas
print("\033[1m For Gas the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinGas))


sigmaminHumidity = (np.std(insidedf["Humidity"]))/np.sqrt(len(insidedf["Humidity"]))
meaninHumidity = np.mean(insidedf["Humidity"])
sigmamoutHumidity = (np.std(outsidedf["Humidity"]))/np.sqrt(len(outsidedf["Humidity"]))
sigmamHumidity = (np.std(insidedf["Humidity"])+np.std(outsidedf["Humidity"]))/np.sqrt(len(outsidedf["Humidity"])+len(insidedf["Humidity"]))
meanoutHumidity = np.mean(outsidedf["Humidity"])
meandiffHumidity = abs(meaninHumidity-meanoutHumidity)
sigmamHumidity3 = 3*abs(sigmamHumidity)

if sigmamHumidity3 < meandiffHumidity:
    print("Humidity data sets are statistically different!")
else:
    print("Humidity data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Humidity mean uncertainty: {:.2f}".format(sigmamHumidity))
sigdiffinHumidity = meandiffHumidity / sigmaminHumidity
print("\033[1m For Humidity the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinHumidity))


sigmaminPressure = (np.std(insidedf["Pressure"]))/np.sqrt(len(insidedf["Pressure"]))
meaninPressure = np.mean(insidedf["Pressure"])
sigmamoutPressure = (np.std(outsidedf["Pressure"]))/np.sqrt(len(outsidedf["Pressure"]))
sigmamPressure = (np.std(insidedf["Pressure"])+np.std(outsidedf["Pressure"]))/np.sqrt(len(outsidedf["Pressure"])+len(insidedf["Pressure"]))
meanoutPressure = np.mean(outsidedf["Pressure"])
meandiffPressure = abs(meaninPressure-meanoutPressure)
sigmamPressure3 = 3*abs(sigmamPressure)

if sigmamPressure3 < meandiffPressure:
    print("Pressure data sets are statistically different!")
else:
    print("Pressure data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pressure mean uncertainty: {:.2f}".format(sigmamPressure))
sigdiffinPressure = meandiffPressure / sigmaminPressure
print("\033[1m For Pressure the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinPressure))


sigmaminAltitude = (np.std(insidedf["Altitude"]))/np.sqrt(len(insidedf["Altitude"]))
meaninAltitude = np.mean(insidedf["Altitude"])
sigmamoutAltitude = (np.std(outsidedf["Altitude"]))/np.sqrt(len(outsidedf["Altitude"]))
sigmamAltitude = (np.std(insidedf["Altitude"])+np.std(outsidedf["Altitude"]))/np.sqrt(len(outsidedf["Altitude"])+len(insidedf["Altitude"]))
meanoutAltitude = np.mean(outsidedf["Altitude"])
meandiffAltitude = abs(meaninAltitude-meanoutAltitude)
sigmamAltitude3 = 3*abs(sigmamAltitude)

if sigmamAltitude3 < meandiffAltitude:
    print("Altitude data sets are statistically different!")
else:
    print("Altitude data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Altitude mean uncertainty: {:.2f}".format(sigmamAltitude))
sigdiffinAltitude = meandiffAltitude / sigmaminAltitude
print("\033[1m For Altitude the inside and outside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinAltitude))
# Out:
# Pm25 data sets are statistically different!
# Pm25 mean uncertainty: 0.04
#  For Pm25 the inside and outside measurements are separated by 168.73 inside mean standard deviations.
# Pm100 data sets are statistically different!
# Pm100 mean uncertainty: 0.06
#  For Pm100 the inside and outside measurements are separated by 31.79 inside mean standard deviations.
# Temperature data sets are statistically different!
# Temperature mean uncertainty: 0.17
#  For Temperature the inside and outside measurements are separated by 834.66 inside mean standard deviations.
# Gas data sets are statistically different!
# Gas mean uncertainty: 3500.04
#  For Gas the inside and outside measurements are separated by 23.21 inside mean standard deviations.
# Humidity data sets are statistically different!
# Humidity mean uncertainty: 0.42
#  For Humidity the inside and outside measurements are separated by 634.50 inside mean standard deviations.
# Pressure data sets are statistically different!
# ...

# %% [markdown]
# Not enough data for central limit theory to be applicable.

# %% [markdown]
# ### Step 2: Comparing sensors
# - Get inside/outside data from another group in your lab and compare your inside data with their inside data, including all of elements from Step 1. - Do the same statistical comparison of your outside data with the outside data from the other group.
# - How do the sensors compare? What do you think this indicates about the accuracy and precision of your sensors?

# %%
sigmamin25 = (np.std(insidedf["Pm25"]))/np.sqrt(len(insidedf["Pm25"]))
g2sigmain25 = (np.std(insidedf2["PM25"]))/np.sqrt(len(insidedf2["PM25"]))
sigmatotin25 = (np.std(insidedf["Pm25"])+np.std(insidedf2["PM25"]))/np.sqrt(len(insidedf["Pm25"])+len(insidedf2["PM25"]))
meanin25 = np.mean(insidedf["Pm25"])
g2meanin25 = np.mean(insidedf2["PM25"])
meandiffin25 = abs(meanin25-g2meanin25)
sigmatotin253 = 3*sigmatotin25

if sigmatotin253 < meandiffin25:
    print("Pm25 inside data sets are statistically different!")
else:
    print("Pm25 inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pm25 inside mean uncertainty: {:.2f}".format(sigmatotin25))
sigdiffin25 = meandiffin25 / sigmamin25
print("\033[1m For Pm25 the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffin25))
    
        
sigmamout25 = (np.std(outsidedf["Pm25"]))/np.sqrt(len(outsidedf["Pm25"]))
g2sigmaout25 = (np.std(outsidedf2["PM25"]))/np.sqrt(len(outsidedf2["PM25"]))
sigmatotout25 = (np.std(outsidedf["Pm25"])+np.std(outsidedf2["PM25"]))/np.sqrt(len(outsidedf["Pm25"])+len(outsidedf2["PM25"]))
meanout25 = np.mean(outsidedf["Pm25"])
g2meanout25 = np.mean(outsidedf2["PM25"])
meandiffout25 = abs(meanout25-g2meanout25)
sigmatotout253 = 3*sigmatotout25

if sigmatotout253 < meandiffout25:
    print("Pm25 outside data sets are statistically different!")
else:
    print("Pm25 outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pm25 outside mean uncertainty: {:.2f}".format(sigmatotout25))
sigdiffout25 = meandiffout25 / g2sigmaout25
print("\033[1m For Pm25 the inside measurements are separated by {:.2f} group 2 inside mean standard deviations. \033[0m".format(sigdiffout25))
    

    
    
sigmamin100 = (np.std(insidedf["Pm100"]))/np.sqrt(len(insidedf["Pm100"]))
g2sigmain100 = (np.std(insidedf2["PM100"]))/np.sqrt(len(insidedf2["PM100"]))
sigmatotin100 = (np.std(insidedf["Pm100"])+np.std(insidedf2["PM100"]))/np.sqrt(len(insidedf["Pm100"])+len(insidedf2["PM100"]))
meanin100 = np.mean(insidedf["Pm100"])
g2meanin100 = np.mean(insidedf2["PM100"])
meandiffin100 = abs(meanin100-g2meanin100)
sigmatotin1003 = 3*sigmatotin100

if sigmatotin1003 < meandiffin100:
    print("Pm100 inside data sets are statistically different!")
else:
    print("Pm100 inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pm100 inside mean uncertainty: {:.2f}".format(sigmatotin100))
sigdiffin100 = meandiffin100 / sigmamin100
print("\033[1m For Pm100 the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffin100))
    

sigmamout100 = (np.std(outsidedf["Pm100"]))/np.sqrt(len(outsidedf["Pm100"]))
g2sigmaout100 = (np.std(outsidedf2["PM100"]))/np.sqrt(len(outsidedf2["PM100"]))
sigmatotout100 = (np.std(outsidedf["Pm100"])+np.std(outsidedf2["PM100"]))/np.sqrt(len(outsidedf["Pm100"])+len(outsidedf2["PM100"]))
meanout100 = np.mean(outsidedf["Pm100"])
g2meanout100 = np.mean(outsidedf2["PM100"])
meandiffout100 = abs(meanout100-g2meanout100)
sigmatotout1003 = 3*sigmatotout100

if sigmatotout1003 < meandiffout100:
    print("Pm100 outside data sets are statistically different!")
else:
    print("Pm100 outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pm100 outside mean uncertainty: {:.2f}".format(sigmatotout100))
sigdiffout100 = meandiffout100 / g2sigmaout100
print("\033[1m For Pm100 the outside measurements are separated by {:.2f} group 2 outside mean standard deviations. \033[0m".format(sigdiffout100))





sigmaminTemp = (np.std(insidedf["Temp"]))/np.sqrt(len(insidedf["Temp"]))
g2sigmainTemp = (np.std(insidedf2["Temperature"]))/np.sqrt(len(insidedf2["Temperature"]))
sigmatotinTemp = (np.std(insidedf["Temp"])+np.std(insidedf2["Temperature"]))/np.sqrt(len(insidedf["Temp"])+len(insidedf2["Temperature"]))
meaninTemp = np.mean(insidedf["Temp"])
g2meaninTemp = np.mean(insidedf2["Temperature"])
meandiffinTemp = abs(meaninTemp-g2meaninTemp)
sigmatotinTemp3 = 3*sigmatotinTemp

if sigmatotinTemp3 < meandiffinTemp:
    print("Temperature inside data sets are statistically different!")
else:
    print("Temperature inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Temperature inside mean uncertainty: {:.2f}".format(sigmatotinTemp))
sigdiffinTemp = meandiffinTemp / sigmaminTemp
print("\033[1m For Temperature the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinTemp))
    
sigmamoutTemp = (np.std(outsidedf["Temp"]))/np.sqrt(len(outsidedf["Temp"]))
g2sigmaoutTemp = (np.std(outsidedf2["Temperature"]))/np.sqrt(len(outsidedf2["Temperature"]))
sigmatotoutTemp = (np.std(outsidedf["Temp"])+np.std(outsidedf2["Temperature"]))/np.sqrt(len(outsidedf["Temp"])+len(outsidedf2["Temperature"]))
meanoutTemp = np.mean(outsidedf["Temp"])
g2meanoutTemp = np.mean(outsidedf2["Temperature"])
meandiffoutTemp = abs(meanoutTemp-g2meanoutTemp)
sigmatotoutTemp3 = 3*sigmatotoutTemp

if sigmatotoutTemp3 < meandiffoutTemp:
    print("Temperature outside data sets are statistically different!")
else:
    print("Temperature outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Temperature outside mean uncertainty: {:.2f}".format(sigmatotoutTemp))
sigdiffoutTemp = meandiffoutTemp / g2sigmaoutTemp
print("\033[1m For Temperature the outside measurements are separated by {:.2f} group 2 outside mean standard deviations. \033[0m".format(sigdiffoutTemp))




sigmaminGas = (np.std(insidedf["Gas"]))/np.sqrt(len(insidedf["Gas"]))
g2sigmainGas = (np.std(insidedf2["Gas"]))/np.sqrt(len(insidedf2["Gas"]))
sigmatotinGas = (np.std(insidedf["Gas"])+np.std(insidedf2["Gas"]))/np.sqrt(len(insidedf["Gas"])+len(insidedf2["Gas"]))
meaninGas = np.mean(insidedf["Gas"])
g2meaninGas = np.mean(insidedf2["Gas"])
meandiffinGas = abs(meaninGas-g2meaninGas)
sigmatotinGas3 = 3*sigmatotinGas

if sigmatotinGas3 < meandiffinGas:
    print("Gas inside data sets are statistically different!")
else:
    print("Gas inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Gas inside mean uncertainty: {:.2f}".format(sigmatotinGas))
sigdiffinGas = meandiffinGas / sigmaminGas
print("\033[1m For Gas the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinGas))
    
sigmamoutGas = (np.std(outsidedf["Gas"]))/np.sqrt(len(outsidedf["Gas"]))
g2sigmaoutGas = (np.std(outsidedf2["Gas"]))/np.sqrt(len(outsidedf2["Gas"]))
sigmatotoutGas = (np.std(outsidedf["Gas"])+np.std(outsidedf2["Gas"]))/np.sqrt(len(outsidedf["Gas"])+len(outsidedf2["Gas"]))
meanoutGas = np.mean(outsidedf["Gas"])
g2meanoutGas = np.mean(outsidedf2["Gas"])
meandiffoutGas = abs(meanoutGas-g2meanoutGas)
sigmatotoutGas3 = 3*sigmatotoutGas

if sigmatotoutGas3 < meandiffoutGas:
    print("Gas outside data sets are statistically different!")
else:
    print("Gas outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Gas outside mean uncertainty: {:.2f}".format(sigmatotoutGas))
sigdiffoutGas = meandiffoutGas / g2sigmaoutGas
print("\033[1m For Gas the outside measurements are separated by {:.2f} group 2 outside mean standard deviations. \033[0m".format(sigdiffoutGas))



sigmaminHumidity = (np.std(insidedf["Humidity"]))/np.sqrt(len(insidedf["Humidity"]))
g2sigmainHumidity = (np.std(insidedf2["Humidity"]))/np.sqrt(len(insidedf2["Humidity"]))
sigmatotinHumidity = (np.std(insidedf["Humidity"])+np.std(insidedf2["Humidity"]))/np.sqrt(len(insidedf["Humidity"])+len(insidedf2["Humidity"]))
meaninHumidity = np.mean(insidedf["Humidity"])
g2meaninHumidity = np.mean(insidedf2["Humidity"])
meandiffinHumidity = abs(meaninHumidity-g2meaninHumidity)
sigmatotinHumidity3 = 3*sigmatotinHumidity

if sigmatotinHumidity3 < meandiffinHumidity:
    print("Humidity inside data sets are statistically different!")
else:
    print("Humidity inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Humidity inside mean uncertainty: {:.2f}".format(sigmatotinHumidity))
sigdiffinHumidity = meandiffinHumidity / sigmaminHumidity
print("\033[1m For Humidity the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinHumidity))
    
sigmamoutHumidity = (np.std(outsidedf["Humidity"]))/np.sqrt(len(outsidedf["Humidity"]))
g2sigmaoutHumidity = (np.std(outsidedf2["Humidity"]))/np.sqrt(len(outsidedf2["Humidity"]))
sigmatotoutHumidity = (np.std(outsidedf["Humidity"])+np.std(outsidedf2["Humidity"]))/np.sqrt(len(outsidedf["Humidity"])+len(outsidedf2["Humidity"]))
meanoutHumidity = np.mean(outsidedf["Humidity"])
g2meanoutHumidity = np.mean(outsidedf2["Humidity"])
meandiffoutHumidity = abs(meanoutHumidity-g2meanoutHumidity)
sigmatotoutHumidity3 = 3*sigmatotoutHumidity

if sigmatotoutHumidity3 < meandiffoutHumidity:
    print("Humidity outside data sets are statistically different!")
else:
    print("Humidity outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Humidity outside mean uncertainty: {:.2f}".format(sigmatotoutHumidity))
sigdiffoutHumidity = meandiffoutHumidity / g2sigmaoutHumidity
print("\033[1m For Humidity the outside measurements are separated by {:.2f} group 2 outside mean standard deviations. \033[0m".format(sigdiffoutHumidity))




sigmaminPressure = (np.std(insidedf["Pressure"]))/np.sqrt(len(insidedf["Pressure"]))
g2sigmainPressure = (np.std(insidedf2["Pressure"]))/np.sqrt(len(insidedf2["Pressure"]))
sigmatotinPressure = (np.std(insidedf["Pressure"])+np.std(insidedf2["Pressure"]))/np.sqrt(len(insidedf["Pressure"])+len(insidedf2["Pressure"]))
meaninPressure = np.mean(insidedf["Pressure"])
g2meaninPressure = np.mean(insidedf2["Pressure"])
meandiffinPressure = abs(meaninPressure-g2meaninPressure)
sigmatotinPressure3 = 3*sigmatotinPressure

if sigmatotinPressure3 < meandiffinPressure:
    print("Pressure inside data sets are statistically different!")
else:
    print("Pressure inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pressure inside mean uncertainty: {:.2f}".format(sigmatotinPressure))
sigdiffinPressure = meandiffinPressure / sigmaminPressure
print("\033[1m For Pressure the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinPressure))
    
sigmamoutPressure = (np.std(outsidedf["Pressure"]))/np.sqrt(len(outsidedf["Pressure"]))
g2sigmaoutPressure = (np.std(outsidedf2["Pressure"]))/np.sqrt(len(outsidedf2["Pressure"]))
sigmatotoutPressure = (np.std(outsidedf["Pressure"])+np.std(outsidedf2["Pressure"]))/np.sqrt(len(outsidedf["Pressure"])+len(outsidedf2["Pressure"]))
meanoutPressure = np.mean(outsidedf["Pressure"])
g2meanoutPressure = np.mean(outsidedf2["Pressure"])
meandiffoutPressure = abs(meanoutPressure-g2meanoutPressure)
sigmatotoutPressure3 = 3*sigmatotoutPressure

if sigmatotoutPressure3 < meandiffoutPressure:
    print("Pressure outside data sets are statistically different!")
else:
    print("Pressure outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Pressure outside mean uncertainty: {:.2f}".format(sigmatotoutPressure))
sigdiffoutPressure = meandiffoutPressure / g2sigmaoutPressure
print("\033[1m For Pressure the outside measurements are separated by {:.2f} group 2 outside mean standard deviations. \033[0m".format(sigdiffoutPressure))






sigmaminAltitude = (np.std(insidedf["Altitude"]))/np.sqrt(len(insidedf["Altitude"]))
g2sigmainAltitude = (np.std(insidedf2["Altitude"]))/np.sqrt(len(insidedf2["Altitude"]))
sigmatotinAltitude = (np.std(insidedf["Altitude"])+np.std(insidedf2["Altitude"]))/np.sqrt(len(insidedf["Altitude"])+len(insidedf2["Altitude"]))
meaninAltitude = np.mean(insidedf["Altitude"])
g2meaninAltitude = np.mean(insidedf2["Altitude"])
meandiffinAltitude = abs(meaninAltitude-g2meaninAltitude)
sigmatotinAltitude3 = 3*sigmatotinAltitude

if sigmatotinAltitude3 < meandiffinAltitude:
    print("Altitude inside data sets are statistically different!")
else:
    print("Altitude inside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Altitude inside mean uncertainty: {:.2f}".format(sigmatotinAltitude))
sigdiffinAltitude = meandiffinAltitude / sigmaminAltitude
print("\033[1m For Altitude the inside measurements are separated by {:.2f} inside mean standard deviations. \033[0m".format(sigdiffinAltitude))
    
sigmamoutAltitude = (np.std(outsidedf["Altitude"]))/np.sqrt(len(outsidedf["Altitude"]))
g2sigmaoutAltitude = (np.std(outsidedf2["Altitude"]))/np.sqrt(len(outsidedf2["Altitude"]))
sigmatotoutAltitude = (np.std(outsidedf["Altitude"])+np.std(outsidedf2["Altitude"]))/np.sqrt(len(outsidedf["Altitude"])+len(outsidedf2["Altitude"]))
meanoutAltitude = np.mean(outsidedf["Altitude"])
g2meanoutAltitude = np.mean(outsidedf2["Altitude"])
meandiffoutAltitude = abs(meanoutAltitude-g2meanoutAltitude)
sigmatotoutAltitude3 = 3*sigmatotoutAltitude

if sigmatotoutAltitude3 < meandiffoutAltitude:
    print("Altitude outside data sets are statistically different!")
else:
    print("Altitude outside data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

print("Altitude outside mean uncertainty: {:.2f}".format(sigmatotoutAltitude))
sigdiffoutAltitude = meandiffoutAltitude / g2sigmaoutAltitude
print("\033[1m For Altitude the outside measurements are separated by {:.2f} group 2 outside mean standard deviations. \033[0m".format(sigdiffoutAltitude))
# Out:
# Pm25 inside data sets are statistically different!
# Pm25 inside mean uncertainty: 0.02
#  For Pm25 the inside measurements are separated by 19.16 inside mean standard deviations.
# Pm25 outside data sets are statistically different!
# Pm25 outside mean uncertainty: 0.03
#  For Pm25 the inside measurements are separated by 147.55 group 2 inside mean standard deviations.
# Pm100 inside data sets are statistically different!
# Pm100 inside mean uncertainty: 0.04
#  For Pm100 the inside measurements are separated by 10.83 inside mean standard deviations.
# Pm100 outside data sets are statistically different!
# Pm100 outside mean uncertainty: 0.05
#  For Pm100 the outside measurements are separated by 30.94 group 2 outside mean standard deviations.
# Temperature inside data sets are statistically different!
# Temperature inside mean uncertainty: 0.01
#  For Temperature the inside measurements are separated by 350.24 inside mean standard deviations.
# ...

# %% [markdown]
# Most of the datasets have relatively low values of mean uncertainty, indicating that the accuracy of the sensors are on-par with one another, however the widely different measurements of inside data and overall temperature for each dataset indicates a lower value of precision for one (or both) of the sensors involved.

# %%
plt.plot(insidedf2["PM25"],label='Group 2 Inside')
plt.plot(insidedf["Pm25"],label='Original Inside')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm25 vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.plot(outsidedf["Pm25"],label='Original Outside')
plt.plot(outsidedf2["PM25"],label='Group 2 Outside')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm25 vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.plot(insidedf2["PM100"],label='Group 2 Inside')
plt.plot(insidedf["Pm100"],label='Original Inside')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm100 vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.plot(outsidedf2["PM100"],label='Group 2 Outside')
plt.plot(outsidedf["Pm100"],label='Original Outside')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm100 vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf["Pm25"],label='Original Inside',)
plt.hist(insidedf2["PM25"],label='Group 2 Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm25 vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Pm25"],label='Original Outside')
plt.hist(outsidedf2["PM25"],label='Group 2 Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm25 vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf2["PM100"],label='Group 2 Inside')
plt.hist(insidedf["Pm100"],label='Original Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm100 vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf2["PM100"],label='Group 2 Outside')
plt.hist(outsidedf["Pm100"],label='Original Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm100 vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf2["Temperature"],label='Group 2 Inside')
plt.hist(insidedf["Temp"],label='Original Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Degrees')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Temperature vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf2["Temperature"],label='Group 2 Outside')
plt.hist(outsidedf["Temp"],label='Original Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Degrees')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Temperature vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf2["Gas"],label='Group 2 Inside')
plt.hist(insidedf["Gas"],label='Original Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Gas vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf2["Gas"],label='Group 2 Outside')
plt.hist(outsidedf["Gas"],label='Original Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Gas vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf2["Humidity"],label='Group 2 Inside')
plt.hist(insidedf["Humidity"],label='Original Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Humidity vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf2["Humidity"],label='Group 2 Outside')
plt.hist(outsidedf["Humidity"],label='Original Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Humidity vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf2["Pressure"],label='Group 2 Inside')
plt.hist(insidedf["Pressure"],label='Original Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Pressure vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf2["Pressure"],label='Group 2 Outside')
plt.hist(outsidedf["Pressure"],label='Original Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Pressure vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %%
plt.hist(insidedf2["Altitude"],label='Group 2 Inside')
plt.hist(insidedf["Altitude"],label='Original Inside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Altitude vs Time for Original and Group 2 Inside Data")                                  
plt.show()

# %%
plt.hist(outsidedf2["Altitude"],label='Group 2 Outside')
plt.hist(outsidedf["Altitude"],label='Original Outside',alpha=0.5)
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Altitude vs Time for Original and Group 2 Outside Data")                                  
plt.show()

# %% [markdown]
# ### Step 3: More locations
# - Consider other areas you could take your sensors where you might find a larger change in the data: for example, is there somewhere near lab where the air quality might be significantly worse?
# - Set up your system to be able to run in a way that would allow you to get to that location and take ~5 minutes of data.
#   - This might require adding additional input arguments, like a delayed start time, or changing to running indefinitely but making sure that your data is being collected and saved even if your script does not run gracefully.
# - Compare this new set of data with your other outdoor data, including the same set of graphs and statistical comparisons made for earlier steps.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

outsideurl = "https://raw.githubusercontent.com/rgorai22/E11_RishikaKatieVic/main/FiveMinOutside.csv" 
outsidedf = pd.read_csv(outsideurl)

insideurl = "https://raw.githubusercontent.com/rgorai22/E11_RishikaKatieVic/main/FiveMinutesInside.csv"
insidedf = pd.read_csv(insideurl)

outsidebadurl = "https://raw.githubusercontent.com/rgorai22/E11_RishikaKatieVic/main/bad_outside.csv"
outsidebad = pd.read_csv(outsidebadurl).drop(50)
display(outsidedf)
outsidedf.describe()
display(insidedf)
insidedf.describe()
display(outsidebad)
outsidebad.describe()
# Out:
#              Time  Pm25  Pm100       Temp     Gas    Humidity     Pressure  \
# 0    1.707957e+09     0      0  33.557930  236730  100.000000   727.240030
# 1    1.707957e+09     0      0  24.594453   22689   42.328480  1005.271764
# 2    1.707957e+09     1      1  24.623359   29622   42.236508  1005.244340
# 3    1.707957e+09     1      1  24.657734   37252   42.109519  1005.229004
# 4    1.707957e+09     1      1  24.692891   45424   41.964882  1005.213153
# ..            ...   ...    ...        ...     ...         ...          ...
# 291  1.707958e+09     1      2  13.799531  261172   67.314556  1004.419332
# 292  1.707958e+09     1      2  13.799727  263155   67.368367  1004.423061
# 293  1.707958e+09     1      2  13.801094  263957   67.395461  1004.420117
# 294  1.707958e+09     1      2  13.801484  262557   67.469501  1004.419031
# 295  1.707958e+09     1      2  13.801680  264562   67.496438  1004.417634
#
#         Altitude
# 0    2711.431262
# 1      66.637026
# ...

# %%
plt.plot(outsidedf["Pm25"],label='Outside')
plt.plot(insidedf["Pm25"],label='Inside')
plt.plot(outsidebad["Pm25"],label='Outside Bad')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm25 vs Time for Inside and Outside Data")                                  
plt.show()

# %%
plt.plot(outsidedf["Pm100"],label='Outside')
plt.plot(insidedf["Pm100"],label='Inside')
plt.plot(outsidebad["Pm100"],label='Outside Bad')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm100 vs Time for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Pm25"],label='Outside')
plt.hist(insidedf["Pm25"],label='Inside')
plt.hist(outsidebad["Pm25"],label='Outside Bad')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm25 vs Time for Inside and Outside Data")                                  
plt.show()

# %%
plt.hist(outsidedf["Pm100"],label='Outside')
plt.hist(insidedf["Pm100"],label='Inside')
plt.hist(outsidebad["Pm100"],label='Outside Bad')
plt.legend(loc='upper right')
plt.ylabel('Counts')                       
plt.xlabel('Time [Since Initial Measurement]')
plt.title("Counts of Pm100 vs Time for Inside and Outside Data")                                  
plt.show()

# %%
sigmambad25 = (np.std(outsidebad["Pm25"]))/np.sqrt(len(outsidebad["Pm25"]))
meanbad25 = np.mean(outsidebad["Pm25"])
sigmamout25 = (np.std(outsidedf["Pm25"]))/np.sqrt(len(outsidedf["Pm25"]))
sigmam25 = (np.std(outsidebad["Pm25"])+np.std(outsidedf["Pm25"]))/np.sqrt(len(outsidedf["Pm25"])+len(outsidebad["Pm25"]))
meanout25 = np.mean(outsidedf["Pm25"])
meandiff25 = abs(meanbad25-meanout25)
sigmam253 = 3*abs(sigmam25)

if sigmam253 < meandiff25:
    print("Pm25 data sets are statistically different!")
else:
    print("Pm25 data sets are statistically similar, means within 3sigma of uncertainty of the mean.")

display("Pm25 mean uncertainty: ",sigmam25)
sigdiffbad25 = meandiff25 / sigmambad25
print("\033[1m For Pm25 the outside bad and outside measurements are separated by {:.2f} outside mean standard deviations. \033[0m".format(sigdiffbad25))
    
sigmam100 = (np.std(outsidebad["Pm100"])+np.std(outsidedf["Pm100"]))/np.sqrt(len(outsidedf["Pm100"])+len(outsidebad["Pm100"]))
sigmambad100 = (np.std(outsidebad["Pm100"]))/np.sqrt(len(outsidebad["Pm100"]))
meanbad100 = np.mean(outsidebad["Pm100"])
sigmamout100 = (np.std(outsidedf["Pm100"]))/np.sqrt(len(outsidedf["Pm100"]))
meanout100 = np.mean(outsidedf["Pm100"])
meandiff100 = abs(meanbad100-meanout100)
sigmam1003 = 3*abs(sigmam100)

if sigmam1003 < meandiff100:
    print("Pm100 data sets are statistically different!")
else:
    print("Pm100 data sets are statistically similar, means within 3sigma of uncertainty of the mean.")
    
display("Pm100 mean uncertainty: ",sigmam100)
sigdiffbad100 = meandiff100 / sigmambad100
print("\033[1m For Pm100 the outside bad and outside measurements are separated by {:.2f} outside mean standard deviations. \033[0m".format(sigdiffbad100))
# Out:
# Pm25 data sets are statistically different!
# 'Pm25 mean uncertainty: '
# 0.060448545513187756
#  For Pm25 the outside bad and outside measurements are separated by 8.45 outside mean standard deviations.
# Pm100 data sets are statistically different!
# 'Pm100 mean uncertainty: '
# 0.07691602907633564
#  For Pm100 the outside bad and outside measurements are separated by 5.24 outside mean standard deviations.

# %% [markdown]
# ### Step 4: Correlations in data
# - Plot temperature vs humidity
#   - NOTE: These were taken by the same sensor at the same time, so each measurement matches up in time, meaning plotting one versus the other works.
#   - What is the hidden variable that is important when making plots like this?
# - What does this plot show? Are temperature and humidity correlated? How would you quantify this?
#   - HINT: there are linear correlation comparisons you can make mathematically such as the Pearson's correlation or similar (linear $R^2$), is the correlation you are seeing linear? Can you implement these in code?
# - Plot temperature vs another property measured by that sensor, are they correlated? Is the correlation qualitatively similar to what you see from temperature vs humidity?
#   - try this for all data types (temp. vs pressure, temp. vs voc, etc.)
#
# - Plot temperature vs PM2.5 concentration and discuss as with the previous comparisons.
#   - This will require coming up with a way to ensure that the times match between sensors, what about the way you are collecting data ensures that this is true?

# %%
plt.scatter(x=outsidedf["Temp"], y=outsidedf["Humidity"], label="Outside")
plt.scatter(x=insidedf["Temp"], y=insidedf["Humidity"], label="Inside")
plt.scatter(x=outsidebad["Temp"], y=outsidebad["Humidity"], label="Outside Bad")
plt.legend() 
plt.xlabel("Temp")
plt.ylabel("Humidity")
plt.title("Temperature vs Humidity")
# Out:
# Text(0.5, 1.0, 'Temperature vs Humidity')

# %%
#calculates pearson correlation (r) between temperature and humidity
out_temphum = outsidedf.corr('pearson').loc["Temp","Humidity"]
in_temphum = insidedf.corr('pearson').loc["Temp","Humidity"]
bad_temphum = outsidebad.corr('pearson').loc["Temp","Humidity"]
print("The outside Pearson correlation between Temperature and Humidity is:", out_temphum)
print("Inside Pearson correlation is:",in_temphum)
print("Outside bad Pearson correlation is:", bad_temphum)
# Out:
# The outside Pearson correlation between Temperature and Humidity is: -0.8603248666247312
# Inside Pearson correlation is: 0.9354110410943756
# Outside bad Pearson correlation is: -0.4027593703166163

# %% [markdown]
# It appears there is some sort of _correlation_ between temperature and humidity for the outside data. The data points seem to linearly decrease, meaning as humidity decreases, temperature increases. However, inside barely changed while outside (when measuring bad air quality) seems to fluxuate even at similar temperatures. The hidden variable could possibly be that temperature and humidity are not directly correlated, but are both affected by a third, unknown variable that is unaccounted for.
#
# Additionally, when observing the correlation values, we can infer that the outside and inside temperature is correlated to humidity, as the value is close to 1.0 or -1.0, while the final outside bad is not as strongly correlated (with a value of 0.4).

# %%
plt.scatter(x=outsidedf["Temp"], y=outsidedf["Pressure"], label="Outside")
plt.scatter(x=insidedf["Temp"], y=insidedf["Pressure"], label="Inside")
plt.scatter(x=outsidebad["Temp"], y=outsidebad["Pressure"], label="Outside Bad")
plt.legend() 
plt.xlabel("Temp")
plt.ylabel("Pressure")
plt.title("Temperature vs Pressure")
# Out:
# Text(0.5, 1.0, 'Temperature vs Pressure')

# %%
#calculates pearson correlation (r) between temperature and Pressure
out_temphum = outsidedf.corr('pearson').loc["Temp","Pressure"]
in_temphum = insidedf.corr('pearson').loc["Temp","Pressure"]
bad_temphum = outsidebad.corr('pearson').loc["Temp","Pressure"]
print("The outside Pearson correlation between Temperature and Pressure is:", out_temphum)
print("Inside Pearson correlation is:",in_temphum)
print("Outside bad Pearson correlation is:", bad_temphum)
# Out:
# The outside Pearson correlation between Temperature and Pressure is: -0.21816964259967495
# Inside Pearson correlation is: -0.966223110117538
# Outside bad Pearson correlation is: -0.2776545241853843

# %% [markdown]
# Using this data, we can conclude that outside temperature is not correlated with pressure whatsoever, as their pearson correlation values are near or close to 0 from 1. However, the inside temperature appears correlated to pressure, but we must take into account the other data points and infer this appearance of correlation can be from other variables affecting the readings, rather than a direct correlation between temperature and pressure inside.

# %%
plt.scatter(x=outsidedf["Temp"], y=outsidedf["Gas"], label="Outside")
plt.scatter(x=insidedf["Temp"], y=insidedf["Gas"], label="Inside")
plt.scatter(x=outsidebad["Temp"], y=outsidebad["Gas"], label="Outside Bad")
plt.legend() 
plt.xlabel("Temp")
plt.ylabel("Gas")
plt.title("Temperature vs Gas")
# Out:
# Text(0.5, 1.0, 'Temperature vs Gas')

# %%
#calculates pearson correlation (r) between temperature and gas
out_temphum = outsidedf.corr('pearson').loc["Temp","Gas"]
in_temphum = insidedf.corr('pearson').loc["Temp","Gas"]
bad_temphum = outsidebad.corr('pearson').loc["Temp","Gas"]
print("The outside Pearson correlation between Temperature and Gas is:", out_temphum)
print("Inside Pearson correlation is:",in_temphum)
print("Outside bad Pearson correlation is:", bad_temphum)
# Out:
# The outside Pearson correlation between Temperature and Gas is: -0.8586745682618746
# Inside Pearson correlation is: 0.12602748312698722
# Outside bad Pearson correlation is: -0.6704166980909309

# %% [markdown]
# Here, outside seems the closest to being correlated, but because of the varying amounts between all three types, the data shows that temperature and gas is not correlated (inside pearson correlation value close to 0, outside bad pearson correlation midway, and outside close to 1).

# %%
plt.scatter(x=outsidedf["Temp"], y=outsidedf["Altitude"], label="Outside")
plt.scatter(x=insidedf["Temp"], y=insidedf["Altitude"], label="Inside")
plt.scatter(x=outsidebad["Temp"], y=outsidebad["Altitude"], label="Outside Bad")
plt.legend() 
plt.xlabel("Temp")
plt.ylabel("Altitude")
plt.title("Temperature vs Altitude")
# Out:
# Text(0.5, 1.0, 'Temperature vs Altitude')

# %%
#calculates pearson correlation (r) between temperature and altitude
out_temphum = outsidedf.corr('pearson').loc["Temp","Altitude"]
in_temphum = insidedf.corr('pearson').loc["Temp","Altitude"]
bad_temphum = outsidebad.corr('pearson').loc["Temp","Altitude"]
print("The outside Pearson correlation between Temperature and Altitude is:", out_temphum)
print("Inside Pearson correlation is:",in_temphum)
print("Outside bad Pearson correlation is:", bad_temphum)
# Out:
# The outside Pearson correlation between Temperature and Altitude is: 0.21984020394120582
# Inside Pearson correlation is: 0.9662427872002691
# Outside bad Pearson correlation is: 0.2797205249084472

# %% [markdown]
# Again, using this data, we can conclude that outside temperature is not correlated with altitude, as their pearson correlation values are near or close to 0 from 1. However, the inside temperature appears correlated to altitude, but we must take into account the other data points and infer this appearance of correlation can be from other variables affecting the readings, rather than a direct correlation between temperature and altitude inside.

# %%
plt.scatter(x=outsidedf["Temp"], y=outsidedf["Pm25"], label="Outside")
plt.scatter(x=insidedf["Temp"], y=insidedf["Pm25"],label="Inside")
plt.scatter(x=outsidebad["Temp"], y=outsidebad["Pm25"], label="Outside Bad")
plt.legend() 
plt.xlabel("Temp")
plt.ylabel("Pm25")
plt.title("Temperature vs Pm25")
# Out:
# Text(0.5, 1.0, 'Temperature vs Pm25')

# %%
#calculates pearson correlation (r) between temperature and pm25
out_temphum = outsidedf.corr('pearson').loc["Temp","Pm25"]
in_temphum = insidedf.corr('pearson').loc["Temp","Pm25"]
bad_temphum = outsidebad.corr('pearson').loc["Temp","Pm25"]
print("The Outside Pearson correlation between Temperature and Pm25 is:", out_temphum)
print("Inside Pearson correlation is:",in_temphum)
print("Outside bad Pearson correlation is:", bad_temphum)
# Out:
# The Outside Pearson correlation between Temperature and Pm25 is: -0.465204531904868
# Inside Pearson correlation is: 0.5083864672495226
# Outside bad Pearson correlation is: -0.18034245787655673

# %% [markdown]
# The Temperature vs. PM2.5 concentration plot ensures that the times match between sensors since the data was collected simultaneously on the sensors. Also, each data point collected by the sensors includes a timestamp indicating the exact time at which the measurement was taken.
